# %% [markdown]
# FOtitos1

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np


img_bgr = cv2.imread('fotito1.jpg')
img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
img_gris = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2GRAY)


cv2.imwrite('fotito1_gris.jpg', img_gris)
cv2.imwrite('fotito1_bgr.jpg', img_bgr)

print("✓ fotito1.jpg cargado y procesado")


plt.figure(figsize=(20, 5))

plt.subplot(1, 4, 1)
plt.imshow(img_rgb)
plt.title('Original (RGB)')
plt.axis('off')

plt.subplot(1, 4, 2)
plt.imshow(img_gris, cmap='gray')
plt.title('Escala de Grises')
plt.axis('off')

plt.subplot(1, 4, 3)
plt.imshow(img_rgb[..., 0], cmap='gray')
plt.title('Canal Rojo (Gris)')
plt.axis('off')

plt.subplot(1, 4, 4)
plt.imshow(img_rgb[..., 0], cmap='Reds')
plt.title('Canal Rojo (Color Falso)')
plt.axis('off')

plt.suptitle('Análisis de presi - Modo 1', fontsize=16)
plt.show()


plt.figure(figsize=(20, 5))

plt.subplot(1, 4, 1)
plt.imshow(img_rgb[..., 1], cmap='gray')
plt.title('Canal Verde (Gris)')
plt.axis('off')

plt.subplot(1, 4, 2)
plt.imshow(img_rgb[..., 1], cmap='Greens')
plt.title('Canal Verde (Color Falso)')
plt.axis('off')

plt.subplot(1, 4, 3)
plt.imshow(img_rgb[..., 2], cmap='gray')
plt.title('Canal Azul (Gris)')
plt.axis('off')

plt.subplot(1, 4, 4)
plt.imshow(img_rgb[..., 2], cmap='Blues')
plt.title('Canal Azul (Color Falso)')
plt.axis('off')

plt.suptitle('Análisis de presi - Modo 2', fontsize=16)
plt.show()

plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.title('imagen original')
plt.imshow(img_rgb)

plt.subplot(1, 2, 2)
plt.title('presi - Escala de Grises')
plt.imshow(img_gris, cmap='gray')

plt.show()
# Out:
# ✓ fotito1.jpg cargado y procesado

# %%
import cv2  
import numpy as np
import matplotlib.pyplot as plt
def isodara(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    umbral = 128
    while true:
        grupo1=image(image<=umbral)
        grupo2=image(image>umbral)
        media1=np.mean(grupo1)
        media2=np.mean(grupo2)
        nuevo_umbral = (media1+media2)/2
        if abs(nuevo_umbral - umbral) < 0.5:
            break
        umbral = nuevo_umbral
        break
        umbral=nuevo_umbral
    return umbral
imagen = cv2.imread('imagen.jpg'.0)
umbral_2_picos=dos_picos(imagen)
_,nueva_imagen=cv2.threshold(imagen,umbral_2_picos,255,cv2.THRESH_BINARY)

# %% [markdown]
# Umbralizacion Variables Particion de una imagen

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
def varianle_part(image,tam_bloque,c):
    umbral_img=np.zeros_like(image)
    for y in range(0,image.shaoe[0],tam_bloque):
        for x in range(0,image.shape[1],tam_bloque):
            bloque=image[y:y+tam_bloque,x:x+tam_bloque]
            varianza=np.var(bloque)
            umbral=c*varianza
            umbral_img[y:y+tam_bloque,x:x+tam_bloque]=umbral
    return umbral_img

# %% [markdown]
# Propiedades locales

# %%
import cv2
import numpy as np  
import = matplotlib.pyplot as plt
image = cv2.imread('image.jpg',0)
def local(image,tamanio,ventana,k):
    umb_img=mp,zeros_like(image)
    pad=tamanop_ventana//2
    padded_image=cv2.copyMakeBorder(image,pad,pad,pad,pad,cv2.BORDER_REPLICATE)
    for y in range(image.shape[0]):
        for x in range(image.shape[1]):
            window=padded_image[y:y+tamanio,x:x+tamanio]
            mean=np.mean(window)
            umb_img[y,x]=255 if image[y,x]>mean+k else 0
    return umb_img
tam_vent=15
k=2
img_fin=local(image,tam_vent,)

# %% [markdown]
# Trabajo

# %%
import cv2 
import numpy as np
import matplotlib.pyplot as plt

imagen = cv2.imread('imagen_16bits.png', 0)  

ventana = 15
k = 2

def adaptive_mean_threshold(imagen, ventana, k):
    alto, ancho = imagen.shape
    salida = np.zeros_like(imagen)
    
    pad = ventana // 2
    imagen_padded = np.pad(imagen, pad, mode='reflect')
    
    for i in range(alto):
        for j in range(ancho):

            region = imagen_padded[i:i+ventana, j:j+ventana]
            media = np.mean(region)

            T = media - k
            if imagen[i, j] > T:
                salida[i, j] = 255
            else:
                salida[i, j] = 0
    
    return salida

imagen_fin = adaptive_mean_threshold(imagen, ventana, k)

plt.figure(figsize=(15,7))

plt.subplot(1,2,1)
plt.title('Imagen Original')
plt.imshow(imagen, cmap='gray')
plt.axis('off')

plt.subplot(1,2,2)
plt.title('Threshold Manual')
plt.imshow(imagen_fin, cmap='gray')
plt.axis('off')

plt.show()
